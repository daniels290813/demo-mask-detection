# %% [markdown]
# # Mask Detection Demo - Training and Evaluation (1 / 3)
#
# The following example demonstrates a training workflow that builds and trains a model that classifies whether a person is wearing a mask or not. The training is auto-logged to both Tensorboard and MLRun, and easily distributed using Horovod. Post training, we will run an evaluation to check our model's performance, updating the logging as a part of a routine test.
#
# 1. [Setup the Project](#section_1)
# 2. [Download the Data](#section_2)
# 3. [Write the Training and Evaluation Code](#section_3)
# 4. [Create the MLRun Function](#section_4)
# 5. [Run Training and Evaluation](#section_5)
# 6. [Run Distributed Training Using Horovod](#section_6)

# %% [markdown]
# Before we continue, we need to install MLRun and the framework of choice (comment and uncomment the framework you wish to use):

# %%
# !pip install mlrun typing-extensions

########## For TF.Keras: ##########
# !pip install mlrun tensorflow

######### For PyTorch:  ##########
# !pip install mlrun torch~=1.13 torchvision~=0.14
# Out:
# Requirement already satisfied: mlrun in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (1.9.0rc5)
# Requirement already satisfied: typing-extensions in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (4.13.2)
# Requirement already satisfied: urllib3<1.27,>=1.26.9 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (1.26.20)
# Requirement already satisfied: GitPython>=3.1.41,~=3.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (3.1.44)
# Requirement already satisfied: aiohttp~=3.11 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (3.11.18)
# Requirement already satisfied: aiohttp-retry~=2.9 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (2.9.1)
# Requirement already satisfied: click~=8.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (8.2.1)
# Requirement already satisfied: nest-asyncio~=1.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (1.6.0)
# Requirement already satisfied: ipython~=8.10 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (8.36.0)
# Requirement already satisfied: nuclio-jupyter~=0.11.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (0.11.1)
# Requirement already satisfied: numpy<1.27.0,>=1.26.4 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (1.26.4)
# Requirement already satisfied: pandas<2.2,>=1.2 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (2.1.4)
# Requirement already satisfied: pyarrow<17,>=10.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (16.1.0)
# Requirement already satisfied: pyyaml<7,>=6.0.2 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (6.0.2)
# Requirement already satisfied: requests~=2.32 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (2.32.3)
# Requirement already satisfied: tabulate~=0.8.6 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (0.8.10)
# Requirement already satisfied: v3io~=0.6.9 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (0.6.12)
# Requirement already satisfied: pydantic>=1.10.15 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (2.11.4)
# Requirement already satisfied: mergedeep~=1.3 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (1.3.4)
# Requirement already satisfied: v3io-frames>=0.13.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (0.13.7)
# Requirement already satisfied: semver~=3.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (3.0.4)
# Requirement already satisfied: dependency-injector~=4.41 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (4.46.0)
# Requirement already satisfied: fsspec<2024.7,>=2023.9.2 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (2024.6.1)
# Requirement already satisfied: v3iofs~=0.1.17 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (0.1.18)
# Requirement already satisfied: storey~=1.9.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (1.9.1)
# Requirement already satisfied: inflection~=0.5.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (0.5.1)
# Requirement already satisfied: python-dotenv~=1.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (1.1.0)
# Requirement already satisfied: setuptools>=75.2 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (78.1.1)
# Requirement already satisfied: deprecated~=1.2 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (1.2.18)
# Requirement already satisfied: jinja2>=3.1.3,~=3.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (3.1.6)
# Requirement already satisfied: orjson<4,>=3.9.15 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (3.10.18)
# Requirement already satisfied: mlrun-pipelines-kfp-common~=0.4.3 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (0.4.3)
# Requirement already satisfied: mlrun-pipelines-kfp-v1-8~=0.4.2 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (0.4.2)
# Requirement already satisfied: docstring_parser~=0.16 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (0.16)
# Requirement already satisfied: aiosmtplib~=3.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (3.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from aiohttp~=3.11->mlrun) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from aiohttp~=3.11->mlrun) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from aiohttp~=3.11->mlrun) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from aiohttp~=3.11->mlrun) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from aiohttp~=3.11->mlrun) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from aiohttp~=3.11->mlrun) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from aiohttp~=3.11->mlrun) (1.20.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from deprecated~=1.2->mlrun) (1.17.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from GitPython>=3.1.41,~=3.1->mlrun) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->GitPython>=3.1.41,~=3.1->mlrun) (5.0.2)
# Requirement already satisfied: decorator in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from ipython~=8.10->mlrun) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from ipython~=8.10->mlrun) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from ipython~=8.10->mlrun) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from ipython~=8.10->mlrun) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from ipython~=8.10->mlrun) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from ipython~=8.10->mlrun) (2.19.1)
# Requirement already satisfied: stack_data in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from ipython~=8.10->mlrun) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from ipython~=8.10->mlrun) (5.14.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jinja2>=3.1.3,~=3.1->mlrun) (3.0.2)
# Requirement already satisfied: kfp_server_api>=1.8.5 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun-pipelines-kfp-common~=0.4.3->mlrun) (1.8.5)
# Requirement already satisfied: kubernetes>=25.3 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun-pipelines-kfp-common~=0.4.3->mlrun) (32.0.1)
# Requirement already satisfied: six>=1.10 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from kfp_server_api>=1.8.5->mlrun-pipelines-kfp-common~=0.4.3->mlrun) (1.17.0)
# Requirement already satisfied: certifi in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from kfp_server_api>=1.8.5->mlrun-pipelines-kfp-common~=0.4.3->mlrun) (2025.4.26)
# Requirement already satisfied: python-dateutil in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from kfp_server_api>=1.8.5->mlrun-pipelines-kfp-common~=0.4.3->mlrun) (2.9.0.post0)
# Requirement already satisfied: nbconvert>=6.4.5 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from nuclio-jupyter~=0.11.1->mlrun) (7.16.6)
# Requirement already satisfied: boto3>=1.28.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from nuclio-jupyter~=0.11.1->mlrun) (1.38.21)
# Requirement already satisfied: importlib-metadata<8.0.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from nuclio-jupyter~=0.11.1->mlrun) (7.2.1)
# Requirement already satisfied: jupyter-server>=2.0.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from nuclio-jupyter~=0.11.1->mlrun) (2.16.0)
# Requirement already satisfied: ipykernel>=5.0.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from nuclio-jupyter~=0.11.1->mlrun) (6.29.5)
# Requirement already satisfied: zipp>=0.5 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from importlib-metadata<8.0.0->nuclio-jupyter~=0.11.1->mlrun) (3.21.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from pandas<2.2,>=1.2->mlrun) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from pandas<2.2,>=1.2->mlrun) (2025.2)
# Requirement already satisfied: wcwidth in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython~=8.10->mlrun) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from requests~=2.32->mlrun) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from requests~=2.32->mlrun) (3.10)
# Requirement already satisfied: xxhash>=1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from storey~=1.9.0->mlrun) (3.5.0)
# Requirement already satisfied: nuclio-sdk>=0.5.3 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from storey~=1.9.0->mlrun) (0.5.15)
# Requirement already satisfied: future>=0.18.2 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from v3io~=0.6.9->mlrun) (1.0.0)
# Requirement already satisfied: botocore<1.39.0,>=1.38.21 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from boto3>=1.28.0->nuclio-jupyter~=0.11.1->mlrun) (1.38.21)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from boto3>=1.28.0->nuclio-jupyter~=0.11.1->mlrun) (1.0.1)
# Requirement already satisfied: s3transfer<0.13.0,>=0.12.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from boto3>=1.28.0->nuclio-jupyter~=0.11.1->mlrun) (0.12.0)
# Requirement already satisfied: appnope in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.1->mlrun) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.1->mlrun) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.1->mlrun) (1.8.14)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.1->mlrun) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.1->mlrun) (5.7.2)
# Requirement already satisfied: packaging in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.1->mlrun) (25.0)
# Requirement already satisfied: psutil in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.1->mlrun) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.1->mlrun) (26.4.0)
# Requirement already satisfied: tornado>=6.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.1->mlrun) (6.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jedi>=0.16->ipython~=8.10->mlrun) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=5.0.0->nuclio-jupyter~=0.11.1->mlrun) (4.3.8)
# Requirement already satisfied: anyio>=3.1.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (4.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (0.22.0)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (1.8.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from argon2-cffi>=21.1->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (21.2.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (4.23.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (3.3.0)
# Requirement already satisfied: referencing in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (0.36.2)
# Requirement already satisfied: rfc3339-validator in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (0.1.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (2025.4.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (0.25.1)
# Requirement already satisfied: fqdn in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (1.5.1)
# Requirement already satisfied: isoduration in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (3.0.0)
# Requirement already satisfied: uri-template in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (24.11.1)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from kubernetes>=25.3->mlrun-pipelines-kfp-common~=0.4.3->mlrun) (2.40.2)
# Requirement already satisfied: requests-oauthlib in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from kubernetes>=25.3->mlrun-pipelines-kfp-common~=0.4.3->mlrun) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from kubernetes>=25.3->mlrun-pipelines-kfp-common~=0.4.3->mlrun) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from kubernetes>=25.3->mlrun-pipelines-kfp-common~=0.4.3->mlrun) (0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=25.3->mlrun-pipelines-kfp-common~=0.4.3->mlrun) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=25.3->mlrun-pipelines-kfp-common~=0.4.3->mlrun) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=25.3->mlrun-pipelines-kfp-common~=0.4.3->mlrun) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=25.3->mlrun-pipelines-kfp-common~=0.4.3->mlrun) (0.6.1)
# Requirement already satisfied: beautifulsoup4 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun) (6.2.0)
# Requirement already satisfied: defusedxml in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun) (1.5.1)
# Requirement already satisfied: webencodings in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from nbformat>=5.3.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (2.21.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from pexpect>4.3->ipython~=8.10->mlrun) (0.7.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from pydantic>=1.10.15->mlrun) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from pydantic>=1.10.15->mlrun) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from pydantic>=1.10.15->mlrun) (0.4.1)
# Requirement already satisfied: googleapis-common-protos>=1.5.3 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from v3io-frames>=0.13.0->mlrun) (1.70.0)
# Requirement already satisfied: grpcio-tools>=1.49 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from v3io-frames>=0.13.0->mlrun) (1.62.3)
# Requirement already satisfied: protobuf~=4.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from v3io-frames>=0.13.0->mlrun) (4.25.7)
# Requirement already satisfied: grpcio>=1.62.3 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from grpcio-tools>=1.49->v3io-frames>=0.13.0->mlrun) (1.71.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (1.17.1)
# Requirement already satisfied: pycparser in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (2.22)
# Requirement already satisfied: soupsieve>1.2 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun) (2.7)
# Requirement already satisfied: arrow>=0.15.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (2.9.0.20250516)
# Requirement already satisfied: executing>=1.2.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from stack_data->ipython~=8.10->mlrun) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from stack_data->ipython~=8.10->mlrun) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from stack_data->ipython~=8.10->mlrun) (0.2.3)
# Requirement already satisfied: mlrun in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (1.9.0rc5)
# Requirement already satisfied: tensorflow in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (2.19.0)
# Requirement already satisfied: urllib3<1.27,>=1.26.9 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (1.26.20)
# Requirement already satisfied: GitPython>=3.1.41,~=3.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (3.1.44)
# Requirement already satisfied: aiohttp~=3.11 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (3.11.18)
# Requirement already satisfied: aiohttp-retry~=2.9 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (2.9.1)
# Requirement already satisfied: click~=8.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (8.2.1)
# Requirement already satisfied: nest-asyncio~=1.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (1.6.0)
# Requirement already satisfied: ipython~=8.10 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (8.36.0)
# Requirement already satisfied: nuclio-jupyter~=0.11.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (0.11.1)
# Requirement already satisfied: numpy<1.27.0,>=1.26.4 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (1.26.4)
# Requirement already satisfied: pandas<2.2,>=1.2 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (2.1.4)
# Requirement already satisfied: pyarrow<17,>=10.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (16.1.0)
# Requirement already satisfied: pyyaml<7,>=6.0.2 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (6.0.2)
# Requirement already satisfied: requests~=2.32 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (2.32.3)
# Requirement already satisfied: tabulate~=0.8.6 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (0.8.10)
# Requirement already satisfied: v3io~=0.6.9 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (0.6.12)
# Requirement already satisfied: pydantic>=1.10.15 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (2.11.4)
# Requirement already satisfied: mergedeep~=1.3 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (1.3.4)
# Requirement already satisfied: v3io-frames>=0.13.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (0.13.7)
# Requirement already satisfied: semver~=3.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (3.0.4)
# Requirement already satisfied: dependency-injector~=4.41 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (4.46.0)
# Requirement already satisfied: fsspec<2024.7,>=2023.9.2 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (2024.6.1)
# Requirement already satisfied: v3iofs~=0.1.17 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (0.1.18)
# Requirement already satisfied: storey~=1.9.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (1.9.1)
# Requirement already satisfied: inflection~=0.5.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (0.5.1)
# Requirement already satisfied: python-dotenv~=1.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (1.1.0)
# Requirement already satisfied: setuptools>=75.2 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (78.1.1)
# Requirement already satisfied: deprecated~=1.2 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (1.2.18)
# Requirement already satisfied: jinja2>=3.1.3,~=3.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (3.1.6)
# Requirement already satisfied: orjson<4,>=3.9.15 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (3.10.18)
# Requirement already satisfied: mlrun-pipelines-kfp-common~=0.4.3 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (0.4.3)
# Requirement already satisfied: mlrun-pipelines-kfp-v1-8~=0.4.2 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (0.4.2)
# Requirement already satisfied: docstring_parser~=0.16 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (0.16)
# Requirement already satisfied: aiosmtplib~=3.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun) (3.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from aiohttp~=3.11->mlrun) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from aiohttp~=3.11->mlrun) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from aiohttp~=3.11->mlrun) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from aiohttp~=3.11->mlrun) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from aiohttp~=3.11->mlrun) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from aiohttp~=3.11->mlrun) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from aiohttp~=3.11->mlrun) (1.20.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from deprecated~=1.2->mlrun) (1.17.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from GitPython>=3.1.41,~=3.1->mlrun) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->GitPython>=3.1.41,~=3.1->mlrun) (5.0.2)
# Requirement already satisfied: decorator in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from ipython~=8.10->mlrun) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from ipython~=8.10->mlrun) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from ipython~=8.10->mlrun) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from ipython~=8.10->mlrun) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from ipython~=8.10->mlrun) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from ipython~=8.10->mlrun) (2.19.1)
# Requirement already satisfied: stack_data in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from ipython~=8.10->mlrun) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from ipython~=8.10->mlrun) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from ipython~=8.10->mlrun) (4.13.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jinja2>=3.1.3,~=3.1->mlrun) (3.0.2)
# Requirement already satisfied: kfp_server_api>=1.8.5 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun-pipelines-kfp-common~=0.4.3->mlrun) (1.8.5)
# Requirement already satisfied: kubernetes>=25.3 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from mlrun-pipelines-kfp-common~=0.4.3->mlrun) (32.0.1)
# Requirement already satisfied: six>=1.10 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from kfp_server_api>=1.8.5->mlrun-pipelines-kfp-common~=0.4.3->mlrun) (1.17.0)
# Requirement already satisfied: certifi in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from kfp_server_api>=1.8.5->mlrun-pipelines-kfp-common~=0.4.3->mlrun) (2025.4.26)
# Requirement already satisfied: python-dateutil in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from kfp_server_api>=1.8.5->mlrun-pipelines-kfp-common~=0.4.3->mlrun) (2.9.0.post0)
# Requirement already satisfied: nbconvert>=6.4.5 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from nuclio-jupyter~=0.11.1->mlrun) (7.16.6)
# Requirement already satisfied: boto3>=1.28.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from nuclio-jupyter~=0.11.1->mlrun) (1.38.21)
# Requirement already satisfied: importlib-metadata<8.0.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from nuclio-jupyter~=0.11.1->mlrun) (7.2.1)
# Requirement already satisfied: jupyter-server>=2.0.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from nuclio-jupyter~=0.11.1->mlrun) (2.16.0)
# Requirement already satisfied: ipykernel>=5.0.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from nuclio-jupyter~=0.11.1->mlrun) (6.29.5)
# Requirement already satisfied: zipp>=0.5 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from importlib-metadata<8.0.0->nuclio-jupyter~=0.11.1->mlrun) (3.21.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from pandas<2.2,>=1.2->mlrun) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from pandas<2.2,>=1.2->mlrun) (2025.2)
# Requirement already satisfied: wcwidth in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython~=8.10->mlrun) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from requests~=2.32->mlrun) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from requests~=2.32->mlrun) (3.10)
# Requirement already satisfied: xxhash>=1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from storey~=1.9.0->mlrun) (3.5.0)
# Requirement already satisfied: nuclio-sdk>=0.5.3 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from storey~=1.9.0->mlrun) (0.5.15)
# Requirement already satisfied: future>=0.18.2 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from v3io~=0.6.9->mlrun) (1.0.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from tensorflow) (4.25.7)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: h5py>=3.11.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from tensorboard~=2.19.0->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: botocore<1.39.0,>=1.38.21 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from boto3>=1.28.0->nuclio-jupyter~=0.11.1->mlrun) (1.38.21)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from boto3>=1.28.0->nuclio-jupyter~=0.11.1->mlrun) (1.0.1)
# Requirement already satisfied: s3transfer<0.13.0,>=0.12.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from boto3>=1.28.0->nuclio-jupyter~=0.11.1->mlrun) (0.12.0)
# Requirement already satisfied: appnope in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.1->mlrun) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.1->mlrun) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.1->mlrun) (1.8.14)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.1->mlrun) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.1->mlrun) (5.7.2)
# Requirement already satisfied: psutil in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.1->mlrun) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.1->mlrun) (26.4.0)
# Requirement already satisfied: tornado>=6.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.1->mlrun) (6.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jedi>=0.16->ipython~=8.10->mlrun) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=5.0.0->nuclio-jupyter~=0.11.1->mlrun) (4.3.8)
# Requirement already satisfied: anyio>=3.1.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (4.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (0.22.0)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (1.8.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from argon2-cffi>=21.1->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (21.2.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (4.23.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (3.3.0)
# Requirement already satisfied: referencing in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (0.36.2)
# Requirement already satisfied: rfc3339-validator in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (0.1.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (2025.4.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (0.25.1)
# Requirement already satisfied: fqdn in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (1.5.1)
# Requirement already satisfied: isoduration in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (3.0.0)
# Requirement already satisfied: uri-template in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (24.11.1)
# Requirement already satisfied: rich in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Requirement already satisfied: optree in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from kubernetes>=25.3->mlrun-pipelines-kfp-common~=0.4.3->mlrun) (2.40.2)
# Requirement already satisfied: requests-oauthlib in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from kubernetes>=25.3->mlrun-pipelines-kfp-common~=0.4.3->mlrun) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from kubernetes>=25.3->mlrun-pipelines-kfp-common~=0.4.3->mlrun) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from kubernetes>=25.3->mlrun-pipelines-kfp-common~=0.4.3->mlrun) (0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=25.3->mlrun-pipelines-kfp-common~=0.4.3->mlrun) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=25.3->mlrun-pipelines-kfp-common~=0.4.3->mlrun) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=25.3->mlrun-pipelines-kfp-common~=0.4.3->mlrun) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=25.3->mlrun-pipelines-kfp-common~=0.4.3->mlrun) (0.6.1)
# Requirement already satisfied: beautifulsoup4 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun) (6.2.0)
# Requirement already satisfied: defusedxml in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun) (1.5.1)
# Requirement already satisfied: webencodings in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from nbformat>=5.3.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (2.21.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from pexpect>4.3->ipython~=8.10->mlrun) (0.7.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from pydantic>=1.10.15->mlrun) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from pydantic>=1.10.15->mlrun) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from pydantic>=1.10.15->mlrun) (0.4.1)
# Requirement already satisfied: googleapis-common-protos>=1.5.3 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from v3io-frames>=0.13.0->mlrun) (1.70.0)
# Requirement already satisfied: grpcio-tools>=1.49 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from v3io-frames>=0.13.0->mlrun) (1.62.3)
# Requirement already satisfied: cffi>=1.0.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (1.17.1)
# Requirement already satisfied: pycparser in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (2.22)
# Requirement already satisfied: soupsieve>1.2 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun) (2.7)
# Requirement already satisfied: arrow>=0.15.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (2.9.0.20250516)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Requirement already satisfied: executing>=1.2.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from stack_data->ipython~=8.10->mlrun) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from stack_data->ipython~=8.10->mlrun) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/Daniel_Sabba/anaconda3/envs/daniel311/lib/python3.11/site-packages (from stack_data->ipython~=8.10->mlrun) (0.2.3)

# %% [markdown]
# <a id="section_1"></a>
# ## 1. Setup the Project
#
# Create a project using `mlrun.get_or_create_project` (make sure to load it in case it already exists), creating the paths where we'll store the project's artifacts:

# %%
import mlrun
import os
import uuid


mlrun.set_env_from_file('mlrun.env')
# Set our project's name:
project_name = "mask-detection2"

# Create the project:
project = mlrun.get_or_create_project(name=project_name, context="./", user_project=True)
# Out:
# > 2025-05-22 16:02:39,413 [info] Identified pre-initialized git repo, using it: {"url":"git://github.com/daniels290813/demo-mask-detection.git#refs/heads/ttt11"}
# > 2025-05-22 16:02:55,001 [info] Created and saved project: {"context":"./","from_template":null,"name":"mask-detection2-admin","overwrite":false,"save":true}
# > 2025-05-22 16:02:55,002 [info] Project created successfully: {"project_name":"mask-detection2-admin","stored_in_db":true}

# %% [markdown]
# A project in MLRun is based on the MLRun Functions it can run. In this notebook we will see two ways to create a MLRun Function:
# * `mlrun.code_to_function`: Create our own MLRun Function from code (will be used for training and evaluation in [section 4](#section_4)).
# * `mlrun.import_function`: Import from [MLRun's functions marketplace](https://docs.mlrun.org/en/latest/load-from-marketplace.html) - a functions hub intended to be a centralized location for open source contributions of function components (will be used for downloading the data in [section 2](#section_2)).
#
# Before we continue, **please select the desired framework** (comment and uncomment the below lines as needed):

# %%
framework = "tf-keras"
# framework = "pytorch"

# If you wish to train on gpu, set this variable to 'True', otherwise 'False':
use_gpu = False

# %% [markdown]
# ### 1.1 Build project image
# Building the image to satisfy the requirements of our project, according to the selection above.

# %%
if framework=='tf-keras':
    commands = ['pip install mlrun tensorflow']
else:
    commands = ['pip install mlrun torch',
                'pip install mlrun tensorboard',
                'pip install mlrun onnx']
    
img = project.build_image(image=f'.mask-detection-{framework}',
                          base_image='mlrun/mlrun-gpu' if use_gpu else 'mlrun/mlrun',
                          commands=commands)
# Out:
# The `overwrite_build_params` parameter default will change from 'False' to 'True' in 1.10.0.
# > 2025-05-22 16:02:55,237 [info] Started building image: .mask-detection-tf-keras
# Enumerating objects: 122, done.
# Counting objects: 100% (23/23), done.
# Compressing objects: 100% (10/10), done.
# Total 122 (delta 15), reused 13 (delta 13), pack-reused 99 (from 1)
# INFO[0001] Retrieving image manifest datanode-registry.iguazio-platform.app.vmdev79.lab.iguazeng.com:80/quay.io/mlrun/mlrun:1.9.0-rc5
# INFO[0001] Retrieving image datanode-registry.iguazio-platform.app.vmdev79.lab.iguazeng.com:80/quay.io/mlrun/mlrun:1.9.0-rc5 from registry datanode-registry.iguazio-platform.app.vmdev79.lab.iguazeng.com:80
# INFO[0001] Built cross stage deps: map[]
# INFO[0001] Retrieving image manifest datanode-registry.iguazio-platform.app.vmdev79.lab.iguazeng.com:80/quay.io/mlrun/mlrun:1.9.0-rc5
# INFO[0001] Returning cached image manifest
# INFO[0001] Executing 0 build triggers
# INFO[0001] Building stage 'datanode-registry.iguazio-platform.app.vmdev79.lab.iguazeng.com:80/quay.io/mlrun/mlrun:1.9.0-rc5' [idx: '0', base-idx: '-1']
# INFO[0001] Unpacking rootfs as cmd ADD . /home/mlrun_code/ requires it.
# INFO[0046] Using files from context: [/kaniko/buildcontext]
# INFO[0046] ADD . /home/mlrun_code/
# INFO[0046] Taking snapshot of files...
# INFO[0046] ENV PYTHONPATH /home/mlrun_code/
# INFO[0046] RUN pip install mlrun tensorflow
# INFO[0046] Initializing snapshotter ...
# INFO[0046] Taking snapshot of full filesystem...
# INFO[0063] Cmd: /bin/sh
# INFO[0063] Args: [-c pip install mlrun tensorflow]
# INFO[0063] Running: [/bin/sh -c pip install mlrun tensorflow]
# Requirement already satisfied: mlrun in /opt/conda/lib/python3.11/site-packages (1.9.0rc5)
# Collecting tensorflow
#   Downloading tensorflow-2.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: urllib3<1.27,>=1.26.9 in /opt/conda/lib/python3.11/site-packages (from mlrun) (1.26.20)
# Requirement already satisfied: GitPython>=3.1.41,~=3.1 in /opt/conda/lib/python3.11/site-packages (from mlrun) (3.1.44)
# Requirement already satisfied: aiohttp~=3.11 in /opt/conda/lib/python3.11/site-packages (from mlrun) (3.11.18)
# Requirement already satisfied: aiohttp-retry~=2.9 in /opt/conda/lib/python3.11/site-packages (from mlrun) (2.9.1)
# Requirement already satisfied: click~=8.1 in /opt/conda/lib/python3.11/site-packages (from mlrun) (8.2.0)
# Requirement already satisfied: nest-asyncio~=1.0 in /opt/conda/lib/python3.11/site-packages (from mlrun) (1.6.0)
# Requirement already satisfied: ipython~=8.10 in /opt/conda/lib/python3.11/site-packages (from mlrun) (8.36.0)
# Requirement already satisfied: nuclio-jupyter~=0.11.1 in /opt/conda/lib/python3.11/site-packages (from mlrun) (0.11.1)
# Requirement already satisfied: numpy<1.27.0,>=1.26.4 in /opt/conda/lib/python3.11/site-packages (from mlrun) (1.26.4)
# Requirement already satisfied: pandas<2.2,>=1.2 in /opt/conda/lib/python3.11/site-packages (from mlrun) (2.1.4)
# Requirement already satisfied: pyarrow<17,>=10.0 in /opt/conda/lib/python3.11/site-packages (from mlrun) (16.1.0)
# Requirement already satisfied: pyyaml<7,>=6.0.2 in /opt/conda/lib/python3.11/site-packages (from mlrun) (6.0.2)
# Requirement already satisfied: requests~=2.32 in /opt/conda/lib/python3.11/site-packages (from mlrun) (2.32.3)
# Requirement already satisfied: tabulate~=0.8.6 in /opt/conda/lib/python3.11/site-packages (from mlrun) (0.8.10)
# Requirement already satisfied: v3io~=0.6.9 in /opt/conda/lib/python3.11/site-packages (from mlrun) (0.6.12)
# Requirement already satisfied: pydantic>=1.10.15 in /opt/conda/lib/python3.11/site-packages (from mlrun) (2.11.4)
# Requirement already satisfied: mergedeep~=1.3 in /opt/conda/lib/python3.11/site-packages (from mlrun) (1.3.4)
# Requirement already satisfied: v3io-frames>=0.13.0 in /opt/conda/lib/python3.11/site-packages (from mlrun) (0.13.6)
# Requirement already satisfied: semver~=3.0 in /opt/conda/lib/python3.11/site-packages (from mlrun) (3.0.4)
# Requirement already satisfied: dependency-injector~=4.41 in /opt/conda/lib/python3.11/site-packages (from mlrun) (4.46.0)
# Requirement already satisfied: fsspec<2024.7,>=2023.9.2 in /opt/conda/lib/python3.11/site-packages (from mlrun) (2024.6.1)
# Requirement already satisfied: v3iofs~=0.1.17 in /opt/conda/lib/python3.11/site-packages (from mlrun) (0.1.18)
# Requirement already satisfied: storey~=1.9.0 in /opt/conda/lib/python3.11/site-packages (from mlrun) (1.9.0)
# Requirement already satisfied: inflection~=0.5.0 in /opt/conda/lib/python3.11/site-packages (from mlrun) (0.5.1)
# Requirement already satisfied: python-dotenv~=1.0 in /opt/conda/lib/python3.11/site-packages (from mlrun) (1.1.0)
# Requirement already satisfied: setuptools>=75.2 in /opt/conda/lib/python3.11/site-packages (from mlrun) (80.7.1)
# Requirement already satisfied: deprecated~=1.2 in /opt/conda/lib/python3.11/site-packages (from mlrun) (1.2.18)
# Requirement already satisfied: jinja2>=3.1.3,~=3.1 in /opt/conda/lib/python3.11/site-packages (from mlrun) (3.1.6)
# Requirement already satisfied: orjson<4,>=3.9.15 in /opt/conda/lib/python3.11/site-packages (from mlrun) (3.10.18)
# Requirement already satisfied: mlrun-pipelines-kfp-common~=0.4.3 in /opt/conda/lib/python3.11/site-packages (from mlrun) (0.4.3)
# Requirement already satisfied: mlrun-pipelines-kfp-v1-8~=0.4.2 in /opt/conda/lib/python3.11/site-packages (from mlrun) (0.4.2)
# Requirement already satisfied: docstring_parser~=0.16 in /opt/conda/lib/python3.11/site-packages (from mlrun) (0.16)
# Requirement already satisfied: aiosmtplib~=3.0 in /opt/conda/lib/python3.11/site-packages (from mlrun) (3.0.2)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Downloading absl_py-2.2.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (4.25.7)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Downloading termcolor-3.1.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.71.0)
# Collecting tensorboard~=2.19.0 (from tensorflow)
#   Downloading tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting keras>=3.5.0 (from tensorflow)
#   Downloading keras-3.10.0-py3-none-any.whl.metadata (6.0 kB)
# Collecting h5py>=3.11.0 (from tensorflow)
#   Downloading h5py-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Collecting ml-dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Downloading ml_dtypes-0.5.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow)
#   Downloading tensorflow_io_gcs_filesystem-0.37.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp~=3.11->mlrun) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.11/site-packages (from aiohttp~=3.11->mlrun) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp~=3.11->mlrun) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from aiohttp~=3.11->mlrun) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.11/site-packages (from aiohttp~=3.11->mlrun) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp~=3.11->mlrun) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp~=3.11->mlrun) (1.20.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.11/site-packages (from GitPython>=3.1.41,~=3.1->mlrun) (4.0.12)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.11/site-packages (from ipython~=8.10->mlrun) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.11/site-packages (from ipython~=8.10->mlrun) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.11/site-packages (from ipython~=8.10->mlrun) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.11/site-packages (from ipython~=8.10->mlrun) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/conda/lib/python3.11/site-packages (from ipython~=8.10->mlrun) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.11/site-packages (from ipython~=8.10->mlrun) (2.19.1)
# Requirement already satisfied: stack_data in /opt/conda/lib/python3.11/site-packages (from ipython~=8.10->mlrun) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /opt/conda/lib/python3.11/site-packages (from ipython~=8.10->mlrun) (5.14.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2>=3.1.3,~=3.1->mlrun) (3.0.2)
# Requirement already satisfied: rich in /opt/conda/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Collecting namex (from keras>=3.5.0->tensorflow)
#   Downloading namex-0.0.9-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.5.0->tensorflow)
#   Downloading optree-0.15.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
# Requirement already satisfied: kfp_server_api>=1.8.5 in /opt/conda/lib/python3.11/site-packages (from mlrun-pipelines-kfp-common~=0.4.3->mlrun) (1.8.5)
# Requirement already satisfied: kubernetes>=25.3 in /opt/conda/lib/python3.11/site-packages (from mlrun-pipelines-kfp-common~=0.4.3->mlrun) (32.0.1)
# Requirement already satisfied: nbconvert>=6.4.5 in /opt/conda/lib/python3.11/site-packages (from nuclio-jupyter~=0.11.1->mlrun) (7.16.6)
# Requirement already satisfied: boto3>=1.28.0 in /opt/conda/lib/python3.11/site-packages (from nuclio-jupyter~=0.11.1->mlrun) (1.35.36)
# Requirement already satisfied: importlib-metadata<8.0.0 in /opt/conda/lib/python3.11/site-packages (from nuclio-jupyter~=0.11.1->mlrun) (7.2.1)
# Requirement already satisfied: jupyter-server>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from nuclio-jupyter~=0.11.1->mlrun) (2.16.0)
# Requirement already satisfied: ipykernel>=5.0.0 in /opt/conda/lib/python3.11/site-packages (from nuclio-jupyter~=0.11.1->mlrun) (6.29.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas<2.2,>=1.2->mlrun) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas<2.2,>=1.2->mlrun) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.11/site-packages (from pandas<2.2,>=1.2->mlrun) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from pydantic>=1.10.15->mlrun) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/conda/lib/python3.11/site-packages (from pydantic>=1.10.15->mlrun) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from pydantic>=1.10.15->mlrun) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests~=2.32->mlrun) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests~=2.32->mlrun) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests~=2.32->mlrun) (2025.4.26)
# Requirement already satisfied: xxhash>=1 in /opt/conda/lib/python3.11/site-packages (from storey~=1.9.0->mlrun) (3.5.0)
# Requirement already satisfied: nuclio-sdk>=0.5.3 in /opt/conda/lib/python3.11/site-packages (from storey~=1.9.0->mlrun) (0.5.15)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.11/site-packages (from tensorboard~=2.19.0->tensorflow) (3.8)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.19.0->tensorflow)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: future>=0.18.2 in /opt/conda/lib/python3.11/site-packages (from v3io~=0.6.9->mlrun) (1.0.0)
# Requirement already satisfied: googleapis-common-protos>=1.5.3 in /opt/conda/lib/python3.11/site-packages (from v3io-frames>=0.13.0->mlrun) (1.70.0)
# Requirement already satisfied: grpcio-tools>=1.49 in /opt/conda/lib/python3.11/site-packages (from v3io-frames>=0.13.0->mlrun) (1.62.3)
# Requirement already satisfied: botocore<1.36.0,>=1.35.36 in /opt/conda/lib/python3.11/site-packages (from boto3>=1.28.0->nuclio-jupyter~=0.11.1->mlrun) (1.35.36)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from boto3>=1.28.0->nuclio-jupyter~=0.11.1->mlrun) (0.10.0)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /opt/conda/lib/python3.11/site-packages (from boto3>=1.28.0->nuclio-jupyter~=0.11.1->mlrun) (0.10.4)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->GitPython>=3.1.41,~=3.1->mlrun) (5.0.2)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.11/site-packages (from importlib-metadata<8.0.0->nuclio-jupyter~=0.11.1->mlrun) (3.21.0)
# Requirement already satisfied: comm>=0.1.1 in /opt/conda/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.1->mlrun) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/conda/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.1->mlrun) (1.8.14)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/conda/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.1->mlrun) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.1->mlrun) (5.7.2)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.1->mlrun) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in /opt/conda/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.1->mlrun) (26.4.0)
# Requirement already satisfied: tornado>=6.1 in /opt/conda/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.1->mlrun) (6.4.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/conda/lib/python3.11/site-packages (from jedi>=0.16->ipython~=8.10->mlrun) (0.8.4)
# Requirement already satisfied: anyio>=3.1.0 in /opt/conda/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (4.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /opt/conda/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /opt/conda/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /opt/conda/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in /opt/conda/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /opt/conda/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /opt/conda/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (0.21.1)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/conda/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /opt/conda/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (1.8.0)
# Requirement already satisfied: google-auth>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from kubernetes>=25.3->mlrun-pipelines-kfp-common~=0.4.3->mlrun) (2.40.1)
# Requirement already satisfied: requests-oauthlib in /opt/conda/lib/python3.11/site-packages (from kubernetes>=25.3->mlrun-pipelines-kfp-common~=0.4.3->mlrun) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /opt/conda/lib/python3.11/site-packages (from kubernetes>=25.3->mlrun-pipelines-kfp-common~=0.4.3->mlrun) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in /opt/conda/lib/python3.11/site-packages (from kubernetes>=25.3->mlrun-pipelines-kfp-common~=0.4.3->mlrun) (0.9)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.11/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in /opt/conda/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun) (6.2.0)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.11/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.11/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/conda/lib/python3.11/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/conda/lib/python3.11/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.11/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun) (1.5.1)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.11/site-packages (from pexpect>4.3->ipython~=8.10->mlrun) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython~=8.10->mlrun) (0.2.13)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.11/site-packages (from rich->keras>=3.5.0->tensorflow) (2.2.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.11/site-packages (from stack_data->ipython~=8.10->mlrun) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.11/site-packages (from stack_data->ipython~=8.10->mlrun) (3.0.0)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.11/site-packages (from stack_data->ipython~=8.10->mlrun) (0.2.3)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/lib/python3.11/site-packages (from argon2-cffi>=21.1->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (21.2.0)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.11/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun) (1.4.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=25.3->mlrun-pipelines-kfp-common~=0.4.3->mlrun) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=25.3->mlrun-pipelines-kfp-common~=0.4.3->mlrun) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=25.3->mlrun-pipelines-kfp-common~=0.4.3->mlrun) (4.9.1)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=5.0.0->nuclio-jupyter~=0.11.1->mlrun) (4.3.8)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/conda/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (4.23.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/conda/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (3.3.0)
# Requirement already satisfied: referencing in /opt/conda/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (0.36.2)
# Requirement already satisfied: rfc3339-validator in /opt/conda/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/conda/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (0.1.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/conda/lib/python3.11/site-packages (from nbformat>=5.3.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (2.21.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun) (2.7)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (2025.4.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (0.25.0)
# Requirement already satisfied: fqdn in /opt/conda/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (1.5.1)
# Requirement already satisfied: isoduration in /opt/conda/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/conda/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (3.0.0)
# Requirement already satisfied: uri-template in /opt/conda/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /opt/conda/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (24.11.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /opt/conda/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=25.3->mlrun-pipelines-kfp-common~=0.4.3->mlrun) (0.6.1)
# Requirement already satisfied: cffi>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (1.17.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /opt/conda/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /opt/conda/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun) (2.9.0.20241206)
# Downloading tensorflow-2.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (644.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.9/644.9 MB 22.6 MB/s eta 0:00:00
# Downloading absl_py-2.2.2-py3-none-any.whl (135 kB)
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading h5py-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 35.9 MB/s eta 0:00:00
# Downloading keras-3.10.0-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 39.6 MB/s eta 0:00:00
# Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 34.8 MB/s eta 0:00:00
# Downloading ml_dtypes-0.5.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 36.8 MB/s eta 0:00:00
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 38.2 MB/s eta 0:00:00
# Downloading tensorflow_io_gcs_filesystem-0.37.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 37.7 MB/s eta 0:00:00
# Downloading termcolor-3.1.0-py3-none-any.whl (7.7 kB)
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 37.3 MB/s eta 0:00:00
# Downloading namex-0.0.9-py3-none-any.whl (5.8 kB)
# Downloading optree-0.15.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (410 kB)
# Installing collected packages: namex, libclang, flatbuffers, termcolor, tensorflow-io-gcs-filesystem, tensorboard-data-server, optree, opt-einsum, ml-dtypes, h5py, google-pasta, gast, astunparse, absl-py, tensorboard, keras, tensorflow

# %% [markdown]
# <a id="section_2"></a>
# ## 2. Download the Data
#
# ### 2.1. Import a Function
#
# We will download the images using `open_archive` - a function from MLRun's functions marketplace. We will import the function using `mlrun.import_function` and describe it to get the function's documentation:

# %%
# Import the function:
open_archive_function = mlrun.import_function("hub://open_archive")

# Print the function's documentation:
open_archive_function.doc()
# Out:
# function: open-archive
# Open a file/object archive into a target directory
# default handler: open_archive
# entry points:
#   open_archive: Open a file/object archive into a target directory. Currently, supports zip and tar.gz.
#     context(MLClientCtx)  - function execution context
#     archive_url(DataItem)  - url of archive file
#     subdir(str)  - path within artifact store where extracted files are stored, default is "/content", default=content/
#     key(str)  - key of archive contents in artifact store, default=content
#     target_path(str)  - file system path to store extracted files, default=None

# %% [markdown]
# ### 2.2. Run the Function - Download the Images
#
# * **Function handlers**: We'll download the images by running the function using the `open_archive` handler as noted in the function's documentation. MLRun function is a collection of code and the handlers are the function headers inside. Every function with a context (type: `mlrun.MLClientCtx`) can be used as a handler.
# * **Passing parameters**: MLRun function expects two types of parameters: inputs (type: `mlrun.DataItem`) and parameters. As noted in the function's documentation, we can see the `archive_url` is an `mlrun.DataItem`, so it should be passed in the `inputs` attribute of the `run` function. The others are passed via the `parameters` attribute.
# * We will use the `local` argument and pass it as `True`. That means we will run the function locally and not on a pod. Using `local` is a convenient way to debug the code.
#
# For more information regarding MLRun functions, context and data items, refer to [MLRun's documentation](https://docs.mlrun.org/en/latest/index.html).

# %%
# Setup the archive url for downloading the dataset images:
archive_url = mlrun.get_sample_path("data/prajnasb-generated-mask-detection/prajnasb_generated_mask_detection.zip")

# Set the path to download the images data to:
# Make sure environment variable `PWD` points to a valid accessible path e.g. `/v3io/projects/mask-detection/`
dataset_path = os.environ.get('PWD', None)+'data/'
dataset_path='/User/projects/demo-mask-detection/data/'
if mlrun.mlconf.is_ce_mode():
    dataset_path = os.path.join(mlrun.mlconf.artifact_path.replace("{{run.project}}", project.name), 'images')

# Run the function using the 'open_archive' handler:
# open_archive_run = open_archive_function.run(
#     name='download_data',
#     handler='open_archive',
#     inputs={'archive_url': archive_url},
#     params={'target_path': dataset_path},
#     local=False
# )

# %% [markdown]
# <a id="section_3"></a>
# ## 3. Write the Training and Evaluation Code

# %% [markdown]
# ### TF.Keras
#
# The code is taken from the python file [training-and-evaluation.py](tf-keras/training-and-evaluation.py), which is classic and straightforward. We:
# 1. Use `_get_datasets` to get the training and validation datasets (on evaluation - the evaluation dataset).
# 2. Use `_get_model` to build our classifier - simple transfer learning from MobileNetV2 (`keras.applications`).
# 3. Call `train` to train the model.
# 4. Call `evaluate` to evaluate the model.
#
# Taking this code one step further is **MLRun**'s framework for `tf.keras`:
#
# ```python
# # Apply MLRun's interface for tf.keras:
# mlrun_tf_keras.apply_mlrun(model=model, context=context, ...)
# ```
#
# With just one line of code, it seamlessly provides **automatic logging** (for both MLRun and Tensorboard) and **distributed training** by wrapping the `fit` and `evaluate` methods of `tf.keras.Model`.
#
# In addition, there is the `TFKerasModelHandler` class that is being returned from `apply_mlrun`. This class supports loading, saving and logging `tf.keras` models with ease, enabling easy versioning of the model and his results, artifacts and custom objects. Pay attention that by default, the model is loaded and logged automatically by `apply_mlrun`.

# %% [markdown]
# ### PyTorch
#
# The code is taken from the python file [training-and-evaluation.py](pytorch/training-and-evaluation.py), which is classic and straightforward. We:
# 1. Use `_get_datasets` to get the training and validation datasets (on evaluation - the evaluation dataset). The function is initiazliing a `MaskDetectionDataset` to handle our images.
# 2. Initialize our `MaskDetector` classifier class - a simple transfer learning from MobileNetV2 (`torchvision.models`).
# 3. Call `train` to train the model.
# 4. Call `evaluate` to evaluate the model.
#
# Taking this code one step further is **MLRun**'s framework for `torch`:
#
# ```python
# import mlrun.frameworks.pytorch as mlrun_torch
# ```
#
# `mlrun_torch` is providing what we call "shortcut functions" for using PyTorch with ease:
# * `train` - Training a model.
# * `evaluate` - Evaluating a model.
#
# Both functions enable **automatic logging** (for both MLRun and Tensorboard) and **distributed training** by simply passing the following parameters: `auto_log: bool` and `use_horovod: bool`.
#
# In addition, you can choose to use our classes directly:
# * `PyTorchMLRunInterface` - the interface for training, evaluating and predicting a PyTorch model. Our code is highly generic and should fit for any type of model.
# * If you wish to use your own training code, to get automatic logging you will simply need to use our callback mechanism with `CallbackHandler`.
# * `PyTorchModelHandler` - supports loading, saving and logging `torch` models with ease, enabling easy versioning of the model and his results, artifacts and custom objects.

# %% [markdown]
# Both **TF.Keras** and **PyTorch** has the same features regarding MLRun's automatic logging and distributed training orchastration:
# * **Automatic logging**: auto-log your training and model to both **Tensorboard** and **MLRun**. Additional settings can be passed onto this method to gain extra logging capabilities, like:
#   * Weights histograms and distributions
#   * Weights statistics
#   * Weights images (working in progress)
#   * Edit static and dynamic hyperparameters tracking
#   * Logging frequency and more
# * **Distributed training with Horovod**: Horovod will be initialized and used automatically if the MLRun Function's `kind` attribute is equal to `"mpijob"`, there won't be any additional changes needed to the original code! More on that later in [section 6](#section_6)
#
# We suggest reading the documentation for further use, or like in this example, use the default settings.

# %% [markdown]
# <a id="section_4"></a>
# ## 4. Create the MLRun Function
#
# We will use MLRun's `mlrun.code_to_function` to create a MLRun Function from our code in the above mentioned python file. Notice our MLRun Function will have two handlers: `train` and `evaluate`.
#
# We wish to run the training first as a Job, so we will set the `kind` parameter to `"job"`.

# %%
# Create the function parsing the given file code using 'code_to_function':
training_and_evaluation_function = mlrun.code_to_function(
    filename=os.path.join(framework, "training-and-evaluation.py"),
    name="training-and-evaluation",
    kind="job",
    image=f'.mask-detection-{framework}'
)

if not mlrun.mlconf.is_ce_mode():
    training_and_evaluation_function.apply(mlrun.auto_mount()) # to enable /User usage

# %% [markdown]
# <a id="section_5"></a>
# ## 5. Run Training and Evaluation
#
# ### 5.1. Train the Model
#
# We will run the training using the `train` handler. We will pass the desired hyperparameters and keep the returning run object in order to pass the trained model to the evaluation (more on that can be seen later on).
#
# Unlike running the `open_archive` function, the training will be performed as a **job** on the **cluster** and not locally.
#
# > **Notice** now the `local` attribute is `False` (this is its default value) which means it will run the function on the cluster. To run the training locally, simply pass `local=True` as before.

# %%
dataset_path='/User/demos/demo-mask-detection/data/'

training_run = training_and_evaluation_function.run(
    name="training",
    handler="train",
    params={
        "dataset_path": dataset_path,
        "batch_size": 32,
        "lr": 1e-4,
        "epochs": 3
    },
    local=False
)
# Out:
# > 2025-05-22 15:53:42,118 [info] Storing function: {"db":"https://mlrun-api.default-tenant.app.vmdev79.lab.iguazeng.com","name":"training","uid":"dd8bfb3c1320481d83f3fdffe3ba7a6f"}
# > 2025-05-22 15:53:42,559 [info] Job is running in the background, pod: training-w999q
# 2025-05-22 12:54:45.458179: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-22 12:54:45.464351: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-22 12:54:45.479170: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747918485.501977       1 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747918485.509852       1 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1747918485.531711       1 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747918485.531745       1 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747918485.531748       1 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747918485.531751       1 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-22 12:54:45.538083: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-05-22 12:54:52.343465: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
# > 2025-05-22 12:55:03,367 [error] Execution error, Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/mlrun/runtimes/local.py", line 506, in exec_from_params
#     val = mlrun.handler(
#           ^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/mlrun/package/__init__.py", line 137, in wrapper
#     func_outputs = func(*args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^
#   File "/mlrun/training-and-evaluation.py", line 192, in train
#     model.fit(
#   File "/opt/conda/lib/python3.11/site-packages/mlrun/frameworks/tf_keras/mlrun_interface.py", line 168, in wrapper
#     result = self.original_fit(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/opt/conda/lib/python3.11/site-packages/mlrun/frameworks/tf_keras/callbacks/logging_callback.py", line 189, in on_train_begin
#     self._setup_run()
#   File "/opt/conda/lib/python3.11/site-packages/mlrun/frameworks/tf_keras/callbacks/logging_callback.py", line 331, in _setup_run
#     self._add_auto_hyperparameters()
#   File "/opt/conda/lib/python3.11/site-packages/mlrun/frameworks/tf_keras/callbacks/logging_callback.py", line 398, in _add_auto_hyperparameters
#     except (KeyError, IndexError, ValueError):
#   File "/opt/conda/lib/python3.11/site-packages/mlrun/frameworks/tf_keras/callbacks/logging_callback.py", line 430, in _get_hyperparameter
#     except KeyError or IndexError as KeyChainError:
# AttributeError: 'Adam' object has no attribute 'lr'
# > 2025-05-22 12:55:03,419 [error] Exec error - 'Adam' object has no attribute 'lr'
# 'Adam' object has no attribute 'lr'
# > 2025-05-22 12:55:03,469 [info] To track results use the CLI: {"info_cmd":"mlrun get run dd8bfb3c1320481d83f3fdffe3ba7a6f -p mask-detection-admin","logs_cmd":"mlrun logs dd8bfb3c1320481d83f3fdffe3ba7a6f -p mask-detection-admin"}
# > 2025-05-22 12:55:03,469 [info] Or click for UI: {"ui_url":"https://dashboard.default-tenant.app.vmdev79.lab.iguazeng.com/mlprojects/mask-detection-admin/jobs/monitor-jobs/training/dd8bfb3c1320481d83f3fdffe3ba7a6f/overview"}
# > 2025-05-22 12:55:03,470 [info] Run execution finished: {"name":"training","status":"error"}
# Runtime error: 'Adam' object has no attribute 'lr'
# <style>
# .dictlist {
#   background-color: #4EC64B;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #4EC64B;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #4EC64B;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#
#   // Get the base URL of the current notebook
#   var baseUrl = window.location.origin;
#
#   // Construct the full URL
#   var fullUrl = new URL(el.title, baseUrl).href;
#
#   document.querySelector(panelName + "-title").innerHTML = fullUrl
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (fullUrl.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", fullUrl);
#   oReq.send();
#
#
#   //iframe.src = fullUrl;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>project</th>
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>end</th>
#       <th>state</th>
#       <th>kind</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>mask-detection-admin</td>
#       <td><div title="dd8bfb3c1320481d83f3fdffe3ba7a6f"><a href="https://dashboard.default-tenant.app.vmdev79.lab.iguazeng.com/mlprojects/mask-detection-admin/jobs/monitor-jobs/training/dd8bfb3c1320481d83f3fdffe3ba7a6f/overview" target="_blank" >...e3ba7a6f</a></div></td>
#       <td>0</td>
#       <td>May 22 12:54:45</td>
#       <td>2025-05-22 12:55:03.397975+00:00</td>
#       <td><div style="color: red;" title="'Adam' object has no attribute 'lr'">error</div></td>
#       <td>run</td>
#       <td>training</td>
#       <td><div class="dictlist">v3io_user=admin</div><div class="dictlist">kind=job</div><div class="dictlist">owner=admin</div><div class="dictlist">mlrun/client_version=1.9.0-rc5</div><div class="dictlist">mlrun/client_python_version=3.11.11</div><div class="dictlist">host=training-w999q</div></td>
#       <td></td>
#       <td><div class="dictlist">dataset_path=/User/demos/demo-mask-detection/data/</div><div class="dictlist">batch_size=32</div><div class="dictlist">lr=0.0001</div><div class="dictlist">epochs=3</div></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="resulta2996900-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="resulta2996900-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="resulta2996900" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="resulta2996900-body"></iframe>
#   </div>
# </div>
# <b> > to track results use the .show() or .logs() methods  or <a href="https://dashboard.default-tenant.app.vmdev79.lab.iguazeng.com/mlprojects/mask-detection-admin/jobs/monitor-jobs/training/dd8bfb3c1320481d83f3fdffe3ba7a6f/overview" target="_blank">click here</a> to open in UI</b>
# > 2025-05-22 15:55:07,497 [info] Run execution finished: {"name":"training","status":"error"}
# > 2025-05-22 15:55:07,498 [error] Run did not finish successfully: {"state":"error","status":{"end_time":"2025-05-22T12:55:03.397975+00:00","error":"'Adam' object has no attribute 'lr'","last_update":"2025-05-22T12:55:05.335000+00:00","start_time":"2025-05-22T12:54:45.052000+00:00","state":"error"}}
# ---------------------------------------------------------------------------
# RunError                                  Traceback (most recent call last)
# Cell In[63], line 3
#       1 dataset_path='/User/demos/demo-mask-detection/data/'
# ----> 3 training_run = training_and_evaluation_function.run(
#       4     name="training",
#       5     handler="train",
#       6     params={
#       7         "dataset_path": dataset_path,
#       8         "batch_size": 32,
#       9         "lr": 1e-4,
#      10         "epochs": 3
#      11     },
#      12     local=False
#      13 )
#
# File ~/anaconda3/envs/daniel311/lib/python3.11/site-packages/mlrun/runtimes/base.py:410, in BaseRuntime.run(self, runspec, handler, name, project, params, inputs, out_path, workdir, artifact_path, watch, schedule, hyperparams, hyper_param_options, verbose, scrape_metrics, local, local_code_path, auto_build, param_file_secrets, notifications, returns, state_thresholds, reset_on_run, **launcher_kwargs)
#     350 """
#     351 Run a local or remote task.
#     352
#    (...)
#     405 :return: Run context object (RunObject) with run metadata, results and status
#     406 """
#     407 launcher = mlrun.launcher.factory.LauncherFactory().create_launcher(
#     408     self._is_remote, local=local, **launcher_kwargs
#     409 )
# --> 410 return launcher.launch(
#     411     runtime=self,
#     412     task=runspec,
#     413     handler=handler,
#     414     name=name,
#     415     project=project,
#     416     params=params,
#     417     inputs=inputs,
#     418     out_path=out_path,
#     419     workdir=workdir,
#     420     artifact_path=artifact_path,
#     421     watch=watch,
#     422     schedule=schedule,
#     423     hyperparams=hyperparams,
#     424     hyper_param_options=hyper_param_options,
#     425     verbose=verbose,
#     426     scrape_metrics=scrape_metrics,
#     427     local_code_path=local_code_path,
#     428     auto_build=auto_build,
#     429     param_file_secrets=param_file_secrets,
#     430     notifications=notifications,
#     431     returns=returns,
#     432     state_thresholds=state_thresholds,
#     433     reset_on_run=reset_on_run,
#     434 )
#
# File ~/anaconda3/envs/daniel311/lib/python3.11/site-packages/mlrun/launcher/remote.py:121, in ClientRemoteLauncher.launch(self, runtime, task, handler, name, project, params, inputs, out_path, workdir, artifact_path, watch, schedule, hyperparams, hyper_param_options, verbose, scrape_metrics, local_code_path, auto_build, param_file_secrets, notifications, returns, state_thresholds, reset_on_run)
#     113 logger.info(
#     114     "Storing function",
#     115     name=run.metadata.name,
#     116     uid=run.metadata.uid,
#     117     db=runtime.spec.rundb,
#     118 )
#     119 self._store_function(runtime, run)
# --> 121 return self._submit_job(runtime, run, schedule, watch)
#
# File ~/anaconda3/envs/daniel311/lib/python3.11/site-packages/mlrun/launcher/remote.py:190, in ClientRemoteLauncher._submit_job(self, runtime, run, schedule, watch)
#     187     run.logs(True, runtime._get_db())
#     188     resp = runtime._get_db_run(run)
# --> 190 return self._wrap_run_result(runtime, resp, run, schedule=schedule)
#
# File ~/anaconda3/envs/daniel311/lib/python3.11/site-packages/mlrun/launcher/base.py:414, in BaseLauncher._wrap_run_result(self, runtime, result, run, schedule, err)
#     408         if runtime._is_remote and not runtime.is_child:
#     409             logger.error(
#     410                 "Run did not finish successfully",
#     411                 state=run.status.state,
#     412                 status=run.status.to_dict(),
#     413             )
# --> 414         raise mlrun.runtimes.utils.RunError(run.error)
#     415     return run
#     417 return None
#
# RunError: 'Adam' object has no attribute 'lr'

# %% [markdown]
# When the training is done, there will be a list of all the <span style="background:lightgreen">artifacts created</span> in MLRun during the training run. All the (hopfully smooth) loss and metrics graphs we all love will be in both MLRun and Tensorboard, as well as the model weights and custom objects.

# %% [markdown]
# ### 5.2. Evaluate the Model
#
# Evaluating the model requires, you guessed it, the trained model. In order to get the model we just trained, we will use the training run object `training_run` that was returned from calling `run` on the MLRun function. Then, to get the model artifact, we will use `training_run.outputs` - a dictionary of all the function's artifacts that can be accessed by their names. So, to get the model, we will use the key "model" (as seen in the artifacts list generated above).

# %%
evaluation_run = training_and_evaluation_function.run(
    name="evaluating",
    handler="evaluate",
    params={
        "model_path": training_run.outputs['model'],  # <- Take the model we trained from the previous MLRun function via the run object.
        "dataset_path": dataset_path,
        "batch_size": 32
    }
)
# Out:
# > 2023-09-05 10:25:46,679 [info] Storing function: {'name': 'evaluating', 'uid': 'a899d1c8d9b5458bbfb6bef7f8e7c119', 'db': 'http://mlrun-api:8080'}
# > 2023-09-05 10:25:46,979 [info] Job is running in the background, pod: evaluating-jzts5
# 2023-09-05 10:26:12.017860: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-09-05 10:26:12.017917: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-09-05 10:26:14.243557: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-09-05 10:26:14.243608: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-09-05 10:26:14.243641: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (evaluating-jzts5): /proc/driver/nvidia/version does not exist
# 2023-09-05 10:26:24.272542: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 43/43 [==============================] - 49s 1s/step - loss: 0.0429 - accuracy: 0.9927
# > 2023-09-05 10:27:21,316 [info] Run execution finished: {'status': 'completed', 'name': 'evaluating'}
# <style>
# .dictlist {
#   background-color: #4EC64B;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #4EC64B;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #4EC64B;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#   console.log(el.title);
#
#   document.querySelector(panelName + "-title").innerHTML = el.title
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (el.title.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", el.title);
#   oReq.send();
#
#
#   //iframe.src = el.title;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>project</th>
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>state</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>mask-detection-iguazio</td>
#       <td><div title="a899d1c8d9b5458bbfb6bef7f8e7c119"><a href="https://dashboard.default-tenant.app.vmdev94.lab.iguazeng.com/mlprojects/mask-detection-iguazio/jobs/monitor/a899d1c8d9b5458bbfb6bef7f8e7c119/overview" target="_blank" >...f8e7c119</a></div></td>
#       <td>0</td>
#       <td>Sep 05 10:26:11</td>
#       <td>completed</td>
#       <td>evaluating</td>
#       <td><div class="dictlist">v3io_user=iguazio</div><div class="dictlist">kind=job</div><div class="dictlist">owner=iguazio</div><div class="dictlist">mlrun/client_version=1.5.0-rc9</div><div class="dictlist">mlrun/client_python_version=3.9.16</div><div class="dictlist">host=evaluating-jzts5</div></td>
#       <td></td>
#       <td><div class="dictlist">model_path=store://artifacts/mask-detection-iguazio/mask_detector:e80c00ef3e69420fbb2e29a17fa053de</div><div class="dictlist">dataset_path=/User/test/demos/mask-detection/data/</div><div class="dictlist">batch_size=32</div></td>
#       <td><div class="dictlist">model_path=store://artifacts/mask-detection-iguazio/mask_detector:e80c00ef3e69420fbb2e29a17fa053de</div><div class="dictlist">dataset_path=/User/test/demos/mask-detection/data/</div><div class="dictlist">batch_size=32</div><div class="dictlist">evaluation_loss=0.042869803517363796</div><div class="dictlist">evaluation_accuracy=0.9927325581395349</div></td>
#       <td><div class="artifact" onclick="expandPanel(this)" paneName="result1b09d639" title="files/v3io/projects/mask-detection-iguazio/artifacts/evaluating/0/evaluation_loss.html.html">evaluation_loss.html</div><div class="artifact" onclick="expandPanel(this)" paneName="result1b09d639" title="files/v3io/projects/mask-detection-iguazio/artifacts/evaluating/0/evaluation_accuracy.html.html">evaluation_accuracy.html</div></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="result1b09d639-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="result1b09d639-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="result1b09d639" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="result1b09d639-body"></iframe>
#   </div>
# </div>
# <b> > to track results use the .show() or .logs() methods  or <a href="https://dashboard.default-tenant.app.vmdev94.lab.iguazeng.com/mlprojects/mask-detection-iguazio/jobs/monitor/a899d1c8d9b5458bbfb6bef7f8e7c119/overview" target="_blank">click here</a> to open in UI</b>
# > 2023-09-05 10:27:25,654 [info] Run execution finished: {'status': 'completed', 'name': 'evaluating'}

# %% [markdown]
# <a id="section_6"></a>
# ## 6. Run Distributed Training Using Horovod
#
# Now we can see the second benefit of MLRun, we can **distribute** our model **training** across **multiple workers** (i.e., perform distributed training), assign **GPUs**, and more. We don't need to bother with Dockerfiles or K8s YAML configuration files — MLRun does all of this for us. We will simply create our function with `kind="mpijob"`.
#
# > **Notice**: for this demo, in order to use GPUs in training, set the `use_gpu` variable to `True`. This will later assign the required configurations to use the GPUs and pass the correct image to support GPUs (image with CUDA libraries).

# %%
# Create the MLRun Function:
mpi_training_and_evaluation_function = mlrun.code_to_function(
    filename=os.path.join(framework, "training-and-evaluation.py"),
    name="mpi-training-and-evaluation",
    handler="train",
    kind="mpijob",
    image=f'.mask-detection-{framework}',
    with_doc=False
)

# %% [markdown]
# We can set additional configurations for our run like image, workers, gpus and more (if `use_gpu` is `True` we will setup 2 workers with 1 GPU per worker):

# %%
# Setup the desired configurations:
mpi_training_and_evaluation_function.spec.replicas = 1
if use_gpu:
    # Select the number of GPUs per replica:
    mpi_training_and_evaluation_function.with_limits(gpus=1)
else:
    mpi_training_and_evaluation_function.with_requests(cpu=2)

# Mount it:
mpi_training_and_evaluation_function.apply(mlrun.auto_mount())

# %%
# community edition mount support
if os.getenv('V3IO_ACCESS_KEY','False')=='False':
    mpi_training_and_evaluation_function.spec.disable_auto_mount=False

# %% [markdown]
# Call run, and notice each epoch is shorter as we now have 2 workers instead of 1. As the 2 workers will print a lot of outputs we would rather wait for completion and then show the results. For that, we will pass `watch=False` and use the run objects function `wait_for_completion` and `show`.
#
# To see the logs, you can go into the UI by clicking the blue hyperlink "<span style="color:blue">**click here**</span>" after running the function:

# %%
# Run the training job:
distributed_training_run = mpi_training_and_evaluation_function.run(
    name="distributed-training",
    params={
        "dataset_path": dataset_path,
        "batch_size": 32,
        "lr": 1e-4,
        "epochs": 3,
    },
    watch=False,  # <- Turn off the logs.
)

# Wait for complition and show the results. 
distributed_training_run.wait_for_completion()
distributed_training_run.show()
# Out:
# > 2023-09-05 10:27:25,906 [info] Storing function: {'name': 'distributed-training', 'uid': '0cb4e7dbe2a2438788038915e789d505', 'db': 'http://mlrun-api:8080'}
# > 2023-09-05 10:28:17,832 [info] MpiJob distributed-training-d3ae842b launcher pod distributed-training-d3ae842b-launcher state active
# <style>
# .dictlist {
#   background-color: #4EC64B;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #4EC64B;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #4EC64B;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#   console.log(el.title);
#
#   document.querySelector(panelName + "-title").innerHTML = el.title
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (el.title.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", el.title);
#   oReq.send();
#
#
#   //iframe.src = el.title;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>project</th>
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>state</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>mask-detection-iguazio</td>
#       <td><div title="0cb4e7dbe2a2438788038915e789d505"><a href="https://dashboard.default-tenant.app.vmdev94.lab.iguazeng.com/mlprojects/mask-detection-iguazio/jobs/monitor/0cb4e7dbe2a2438788038915e789d505/overview" target="_blank" >...e789d505</a></div></td>
#       <td>0</td>
#       <td>Sep 05 10:27:26</td>
#       <td>running</td>
#       <td>distributed-training</td>
#       <td><div class="dictlist">v3io_user=iguazio</div><div class="dictlist">kind=mpijob</div><div class="dictlist">owner=iguazio</div><div class="dictlist">mlrun/client_version=1.5.0-rc9</div><div class="dictlist">mlrun/client_python_version=3.9.16</div></td>
#       <td></td>
#       <td><div class="dictlist">dataset_path=/User/test/demos/mask-detection/data/</div><div class="dictlist">batch_size=32</div><div class="dictlist">lr=0.0001</div><div class="dictlist">epochs=3</div></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="resultfa765f31-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="resultfa765f31-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="resultfa765f31" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="resultfa765f31-body"></iframe>
#   </div>
# </div>
# <b> > to track results use the .show() or .logs() methods  or <a href="https://dashboard.default-tenant.app.vmdev94.lab.iguazeng.com/mlprojects/mask-detection-iguazio/jobs/monitor/0cb4e7dbe2a2438788038915e789d505/overview" target="_blank">click here</a> to open in UI</b>
# > 2023-09-05 10:28:17,853 [info] Run execution finished: {'status': 'running', 'name': 'distributed-training'}
# > 2023-09-05 10:28:17,877 [info] run distributed-training is not completed yet, waiting for it to complete: {'current_state': 'running'}
# + POD_NAME=distributed-training-d3ae842b-worker-0
# + shift
# + /opt/kube/kubectl exec distributed-training-d3ae842b-worker-0 -- /bin/sh -c  orted -mca ess "env" -mca ess_base_jobid "2329411584" -mca ess_base_vpid 1 -mca ess_base_num_procs "2" -mca orte_node_regex "distributed-training-d[1:3]ae842b-launcher,distributed-training-d[1:3]ae842b-worker-0@0(2)" -mca orte_hnp_uri "2329411584.0;tcp://10.233.67.47:37575" -mca plm "rsh" --tree-spawn -mca routed "radix" -mca orte_parent_uri "2329411584.0;tcp://10.233.67.47:37575" -mca plm_rsh_agent "/etc/mpi/kubexec.sh" -mca orte_default_hostfile "/etc/mpi/hostfile" -mca pmix "^s1,s2,cray,isolated"
# 2023-09-05 10:28:22.201858: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-09-05 10:28:22.201904: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-09-05 10:28:24.415602: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-09-05 10:28:24.415655: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-09-05 10:28:24.415691: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (distributed-training-d3ae842b-worker-0): /proc/driver/nvidia/version does not exist
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# 2023-09-05 10:28:33.778812: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step
# The `lr` argument is deprecated, use `learning_rate` instead.
# Horovod worker #0 is using CPU
# Epoch 1/3
# 35/35 [==============================] - 96s 3s/step - loss: 0.5084 - accuracy: 0.7736 - val_loss: 0.1132 - val_accuracy: 0.9783 - lr: 1.0000e-04
# Epoch 2/3
# 35/35 [==============================] - 89s 3s/step - loss: 0.1301 - accuracy: 0.9618 - val_loss: 0.0609 - val_accuracy: 0.9855 - lr: 1.0000e-04
# Epoch 3/3
# 35/35 [==============================] - 88s 3s/step - loss: 0.0730 - accuracy: 0.9782 - val_loss: 0.0465 - val_accuracy: 0.9855 - lr: 1.0000e-04
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 52). These functions will not be directly callable after loading.
# > 2023-09-05 10:33:28,738 [info] Run execution finished: {'status': 'running', 'name': 'distributed-training'}
# <style>
# .dictlist {
#   background-color: #4EC64B;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #4EC64B;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #4EC64B;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#   console.log(el.title);
#
#   document.querySelector(panelName + "-title").innerHTML = el.title
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (el.title.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", el.title);
#   oReq.send();
#
#
#   //iframe.src = el.title;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>project</th>
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>state</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>mask-detection-iguazio</td>
#       <td><div title="0cb4e7dbe2a2438788038915e789d505"><a href="https://dashboard.default-tenant.app.vmdev94.lab.iguazeng.com/mlprojects/mask-detection-iguazio/jobs/monitor/0cb4e7dbe2a2438788038915e789d505/overview" target="_blank" >...e789d505</a></div></td>
#       <td>0</td>
#       <td>Sep 05 10:28:21</td>
#       <td>completed</td>
#       <td>distributed-training</td>
#       <td><div class="dictlist">v3io_user=iguazio</div><div class="dictlist">kind=mpijob</div><div class="dictlist">owner=iguazio</div><div class="dictlist">mlrun/client_version=1.5.0-rc9</div><div class="dictlist">mlrun/client_python_version=3.9.16</div><div class="dictlist">mlrun/job=distributed-training-d3ae842b</div><div class="dictlist">host=distributed-training-d3ae842b-worker-0</div></td>
#       <td></td>
#       <td><div class="dictlist">dataset_path=/User/test/demos/mask-detection/data/</div><div class="dictlist">batch_size=32</div><div class="dictlist">lr=0.0001</div><div class="dictlist">epochs=3</div></td>
#       <td><div class="dictlist">dataset_path=/User/test/demos/mask-detection/data/</div><div class="dictlist">batch_size=32</div><div class="dictlist">epochs=3</div><div class="dictlist">lr=9.999999747378752e-05</div><div class="dictlist">training_loss=0.040120527148246765</div><div class="dictlist">training_accuracy=1.0004091262817383</div><div class="dictlist">validation_loss=0.04653192311525345</div><div class="dictlist">validation_accuracy=0.9855072498321533</div></td>
#       <td><div class="artifact" onclick="expandPanel(this)" paneName="resultabaa14dc" title="files/v3io/projects/mask-detection-iguazio/artifacts/distributed-training/0/training_loss.html.html">training_loss.html</div><div class="artifact" onclick="expandPanel(this)" paneName="resultabaa14dc" title="files/v3io/projects/mask-detection-iguazio/artifacts/distributed-training/0/training_accuracy.html.html">training_accuracy.html</div><div class="artifact" onclick="expandPanel(this)" paneName="resultabaa14dc" title="files/v3io/projects/mask-detection-iguazio/artifacts/distributed-training/0/validation_loss.html.html">validation_loss.html</div><div class="artifact" onclick="expandPanel(this)" paneName="resultabaa14dc" title="files/v3io/projects/mask-detection-iguazio/artifacts/distributed-training/0/validation_accuracy.html.html">validation_accuracy.html</div><div class="artifact" onclick="expandPanel(this)" paneName="resultabaa14dc" title="files/v3io/projects/mask-detection-iguazio/artifacts/distributed-training/0/loss_summary.html.html">loss_summary.html</div><div class="artifact" onclick="expandPanel(this)" paneName="resultabaa14dc" title="files/v3io/projects/mask-detection-iguazio/artifacts/distributed-training/0/accuracy_summary.html.html">accuracy_summary.html</div><div class="artifact" onclick="expandPanel(this)" paneName="resultabaa14dc" title="files/v3io/projects/mask-detection-iguazio/artifacts/distributed-training/0/lr_values.html.html">lr_values.html</div><div title="v3io:///projects/mask-detection-iguazio/artifacts/distributed-training/0/model/">model</div></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="resultabaa14dc-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="resultabaa14dc-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="resultabaa14dc" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="resultabaa14dc-body"></iframe>
#   </div>
# </div>
